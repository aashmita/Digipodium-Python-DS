# %% [markdown]
# # 13 July 2026
#
# - pip install streamlit
# - import streamlit as st
# - python -m streamlit run filename.py
#
# Web page opens in local browser means -> everything okay
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# st.title("Welcome to my Dashboard")
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Science
#
# - Data Mining
# - Extracting data from any website

# %% [markdown]
# # 14 June
# - web apps - output is shown in server
#
# We have flask and streamlit - libraries
#
# industry project - frontend , backend , database
# end to end applications
# from scratch UI
#
# - Streamlit is a basic library - UI library
# ready to use components
# Data matters more than ui
#
# Drawbacks :
# - Limited Components
# Same UI everywhere

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
