# %% [markdown]
# ## Conditional Statements - 25 May 2026

# %%
# find largest from 3 numbers

a, b, c = 40, 80, 50

if a>b:
    if a>c:
        print(f'{a} is largest')

    else:
        print(f'{c} is largest')

else:
    if b>c:
        print(f'{b} is largest')
    else:
        print(f'{c} is largest')
# Out:
# 80 is largest
