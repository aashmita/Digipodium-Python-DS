# %% [markdown]
# take first name and print starting 2 characters from it
# string and loop - 11/06/26

# %%
x = 'all is well'
x.upper()
# Out:
# 'ALL IS WELL'

# %%
x.lower()
# Out:
# 'all is well'

# %%
x.capitalize  // All is well
# Out:
# <function str.capitalize()>

# %%
x.title()
# Out:
# 'All Is Well'

# %%
x*5
# Out:
# 'all is wellall is wellall is wellall is wellall is well'

# %%
poem = '''Johnny Johnny yes papa
eating sugar no papa
telling a lie no papa
open your mouth hahaha'''

print(poem)
# Out:
# Johnny Johnny yes papa
# eating sugar no papa
# telling a lie no papa
# open your mouth hahaha

# %%
poem.find('papa')
# Out:
# 18

# %%
p = poem.replace('papa','fufa').replace('sugar','salt')
print(p)
# Out:
# Johnny Johnny yes fufa
# eating salt no fufa
# telling a lie no fufa
# open your mouth hahaha

# %%
text = " hello world "
text.strip()     #removes trailing and ending white spaces excess spaces
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['all', 'is', 'well']

# %%
poem.splitlines()
# Out:
# ['Johnny Johnny yes papa',
#  'eating sugar no papa',
#  'telling a lie no papa',
#  'open your mouth hahaha']

# %%
x.count('l') #counts ocurrence of character
# Out:
# 4

# %%
type("Hello")
# Out:
# str

# %%
5+2*3
# Out:
# 11

# %%
2^3
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
10//3    # divides two number and returns remainder
# Out:
# 3

# %%
x=10
if x>5:
    print("A")
else:
    print("B")
# Out:
# A

# %%
x = 10if x > 5:  print("A")else:  print("B")
# Out:
# <>:1: SyntaxWarning: invalid decimal literal
# <>:1: SyntaxWarning: invalid decimal literal
# C:\Users\PILR\AppData\Local\Temp\ipykernel_13436\1292407109.py:1: SyntaxWarning: invalid decimal literal
#   x = 10if x > 5:  print("A")else:  print("B")
#   Cell In[7], line 1
#     x = 10if x > 5:  print("A")else:  print("B")
#                   ^
# SyntaxError: invalid syntax

# %%
s = "Python"
print(s[-1])
# Out:
# n

# %%
print s[-1]
# Out:
#   Cell In[9], line 1
#     print s[-1]
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
x="5"
y=2
print(x*y)
# Out:
# 55

# %%
for i in "Hi":
    print(i)
# Out:
# H
# i
