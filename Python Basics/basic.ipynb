# %% [markdown]
# #python notebook

# %%
print(123)
# Out:
# 123

# %% [markdown]
# # heading1

# %% [markdown]
# ## heading2

# %% [markdown]
# ### heading3

# %% [markdown]
# #### heading4

# %% [markdown]
# `demo code`

# %% [markdown]
# - point1
# - point2
#     - point2.1
#         - point 2.1.1

# %% [markdown]
# - heading -> #shift enter (#)
# - bullet -> dash (-)
# - highlight -> backtick `abc`( ` )

# %% [markdown]
# hh
