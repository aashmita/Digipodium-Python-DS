# %% [markdown]
# ## 21 June 2026

# %%
from datetime import datetime as dt

# %%
import os 

total_folders = 0
total_files = 0
for path,folders,files in os.walk(os.getcwd()):
    print("Current path : ", path)
    print("Folders: ",folders)
    total_folders += len(folders)
    total_files = len(files)

print("Total Folders: ", total_folders)
print("Total_files:",total_files)
# Out:
# Current path :  c:\Digipod
# Folders:  ['.git']
# Current path :  c:\Digipod\.git
# Folders:  ['hooks', 'info', 'logs', 'objects', 'refs']
# Current path :  c:\Digipod\.git\hooks
# Folders:  []
# Current path :  c:\Digipod\.git\info
# Folders:  []
# Current path :  c:\Digipod\.git\logs
# Folders:  ['refs']
# Current path :  c:\Digipod\.git\logs\refs
# Folders:  ['heads', 'remotes']
# Current path :  c:\Digipod\.git\logs\refs\heads
# Folders:  []
# Current path :  c:\Digipod\.git\logs\refs\remotes
# Folders:  ['origin']
# Current path :  c:\Digipod\.git\logs\refs\remotes\origin
# Folders:  []
# Current path :  c:\Digipod\.git\objects
# Folders:  ['0d', '12', '24', '38', '63', '79', '7c', '95', 'ab', 'ae', 'af', 'b6', 'fc', 'ff', 'info', 'pack']
# Current path :  c:\Digipod\.git\objects\0d
# Folders:  []
# Current path :  c:\Digipod\.git\objects\12
# Folders:  []
# Current path :  c:\Digipod\.git\objects\24
# Folders:  []
# Current path :  c:\Digipod\.git\objects\38
# Folders:  []
# Current path :  c:\Digipod\.git\objects\63
# Folders:  []
# Current path :  c:\Digipod\.git\objects\79
# Folders:  []
# Current path :  c:\Digipod\.git\objects\7c
# Folders:  []
# Current path :  c:\Digipod\.git\objects\95
# Folders:  []
# Current path :  c:\Digipod\.git\objects\ab
# Folders:  []
# Current path :  c:\Digipod\.git\objects\ae
# Folders:  []
# Current path :  c:\Digipod\.git\objects\af
# Folders:  []
# Current path :  c:\Digipod\.git\objects\b6
# Folders:  []
# Current path :  c:\Digipod\.git\objects\fc
# Folders:  []
# Current path :  c:\Digipod\.git\objects\ff
# Folders:  []
# Current path :  c:\Digipod\.git\objects\info
# Folders:  []
# Current path :  c:\Digipod\.git\objects\pack
# Folders:  []
# Current path :  c:\Digipod\.git\refs
# Folders:  ['heads', 'remotes', 'tags']
# Current path :  c:\Digipod\.git\refs\heads
# Folders:  []
# Current path :  c:\Digipod\.git\refs\remotes
# Folders:  ['origin']
# Current path :  c:\Digipod\.git\refs\remotes\origin
# Folders:  []
# Current path :  c:\Digipod\.git\refs\tags
# Folders:  []
# Total Folders:  30
# Total_files: 0

# %%
print("formatted date is",dt.now().strftime("%Y-%m-%d"))
print("formatted time is",dt.now().strftime("%H:%M:%S"))
print("Current month name",dt.now().strftime("%B"))
print("Current month name",dt.now().strftime("%b"))
print("Current day name",dt.now().strftime("%A"))
print("Current day name",dt.now().strftime("%a"))
# Out:
# formatted date is 2026-06-21
# formatted time is 15:27:18
# Current month name June
# Current month name Jun
# Current day name Sunday
# Current day name Sun

# %% [markdown]
# #24 june 2026

# %%
import os
print("Get current working directory", os.getcwd())
print("List all the directories and files in current working directory: ", os.listdir())
# Out:
# Get current working directory c:\Digipod
# List all the directories and files in current working directory:  ['.git', 'armstrong.py', 'base.py', 'basic.ipynb', 'conditions.ipynb', 'datatypes.ipynb', 'functions.ipynb', 'libraries.ipynb', 'loops.ipynb', 'palindrome.py', 'string.ipynb']

# %%
# gives all the listed files, path, folders
for path,folders,files in os.walk(os.getcwd()):
    print("Current path:",path)

# %% [markdown]
# ### Libraries
# - math
# - random
# - datetime
# - os
